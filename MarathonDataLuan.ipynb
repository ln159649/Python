# %%
# https://www.kaggle.com/datasets/aiaiaidavid/the-big-dataset-of-ultra-marathon-running/discussion/420633

# %%
#import libaries

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES2025.csv")
# Out:
# C:\Users\luann\AppData\Local\Temp\ipykernel_21240\1707084772.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES2025.csv")

# %%
#See the data that's been imported

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#clean up data

# %%
#Only want USA Races, 50k or 50miles, 2020

# %%
#step 1 show 50km or 50 miles
#50km
#50mi

# %%
df[df['Event distance/length'] == '50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#show only 50km or 50mi

# %%
df[df['Event distance/length'].isin(['50km', '50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#show only 2020 data

# %%
df[(df['Event distance/length'].isin(['50km', '50mi']))     &   (df['Year of event'] == 2018)     ]
# Out:
#         Year of event     Event dates                 Event name  \
# 0                2018      06.01.2018        Selva Costera (CHI)
# 1                2018      06.01.2018        Selva Costera (CHI)
# 2                2018      06.01.2018        Selva Costera (CHI)
# 3                2018      06.01.2018        Selva Costera (CHI)
# 4                2018      06.01.2018        Selva Costera (CHI)
# ...               ...             ...                        ...
# 661478           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661479           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661480           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661481           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661482           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
#
#        Event distance/length  Event number of finishers Athlete performance  \
# 0                       50km                         22           4:51:39 h
# ...

# %%
#see only USA events

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#combine filters together

# %%
df[(df['Event distance/length'].isin(['50km', '50mi']))  & (df['Year of event'] == 2018) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA') ]
# Out:
#         Year of event     Event dates  \
# 55               2018      06.01.2018
# 56               2018      06.01.2018
# 57               2018      06.01.2018
# 58               2018      06.01.2018
# 59               2018      06.01.2018
# ...               ...             ...
# 661478           2018  27.-28.10.2018
# 661479           2018  27.-28.10.2018
# 661480           2018  27.-28.10.2018
# 661481           2018  27.-28.10.2018
# 661482           2018  27.-28.10.2018
#
#                                            Event name Event distance/length  \
# 55      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
FilteredDF = df[(df['Event distance/length'].isin(['50km', '50mi']))  & (df['Year of event'] == 2018) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA') ]

# %%
FilteredDF.head(10)
# Out:
#     Year of event Event dates                                     Event name  \
# 55           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 56           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 57           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 58           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 59           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 60           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 61           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 62           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 63           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 64           2018  06.01.2018    Yankee Springs 50 km Winter Challenge (USA)
#
#    Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
FilteredDF.shape
# Out:
# (64299, 13)

# %%
#remove (USA) from event name

# %%
FilteredDF['Event name'].str.split('(').str.get(0)
# Out:
# 55        Yankee Springs 50 Mile Winter Challenge
# 56        Yankee Springs 50 Mile Winter Challenge
# 57        Yankee Springs 50 Mile Winter Challenge
# 58        Yankee Springs 50 Mile Winter Challenge
# 59        Yankee Springs 50 Mile Winter Challenge
#                             ...
# 661478                        Cactus Rose 50 Mile
# 661479                        Cactus Rose 50 Mile
# 661480                        Cactus Rose 50 Mile
# 661481                        Cactus Rose 50 Mile
# 661482                        Cactus Rose 50 Mile
# Name: Event name, Length: 64299, dtype: object

# %%
FilteredDF['Event name'] = FilteredDF['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\luann\AppData\Local\Temp\ipykernel_21240\1172597318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FilteredDF['Event name'] = FilteredDF['Event name'].str.split('(').str.get(0)

# %%
FilteredDF.head()
# Out:
#     Year of event Event dates                                Event name  \
# 55           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 56           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 57           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 58           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 59           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
#
#    Event distance/length  Event number of finishers Athlete performance  \
# 55                  50mi                          9           9:53:05 h
# 56                  50mi                          9          11:09:35 h
# 57                  50mi                          9          11:33:00 h
# 58                  50mi                          9          11:38:17 h
# 59                  50mi                          9          11:56:35 h
#
#         Athlete club Athlete country  Athlete year of birth Athlete gender  \
# ...

# %%
#Clean up athlete age

# %%
FilteredDF['athlete_age'] = 2020 - FilteredDF['Athlete year of birth']
# Out:
# C:\Users\luann\AppData\Local\Temp\ipykernel_21240\117831342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FilteredDF['athlete_age'] = 2020 - FilteredDF['Athlete year of birth']

# %%
#remove h from athlete performance

# %%
FilteredDF['Athlete performance'] = FilteredDF['Athlete performance'].str.split('').str.get(0)
# Out:
# C:\Users\luann\AppData\Local\Temp\ipykernel_21240\2404238828.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FilteredDF['Athlete performance'] = FilteredDF['Athlete performance'].str.split('').str.get(0)

# %%
FilteredDF.head(5)
# Out:
#     Year of event Event dates                                Event name  \
# 55           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 56           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 57           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 58           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 59           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
#
#    Event distance/length  Event number of finishers Athlete performance  \
# 55                  50mi                          9
# 56                  50mi                          9
# 57                  50mi                          9
# 58                  50mi                          9
# 59                  50mi                          9
#
#         Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 55  *Middleville, MI             USA                 1983.0              M
# ...

# %%
#Drop unneccessary columns: Athlete Club, Athlete country, Athlete Year of Birth, Athlete Age Category

# %%
FilteredDF = FilteredDF.drop(['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], axis=1)

# %%
FilteredDF.head(5)
# Out:
#     Year of event Event dates                                Event name  \
# 55           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 56           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 57           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 58           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 59           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
#
#    Event distance/length  Event number of finishers Athlete performance  \
# 55                  50mi                          9
# 56                  50mi                          9
# 57                  50mi                          9
# 58                  50mi                          9
# 59                  50mi                          9
#
#    Athlete gender Athlete average speed  Athlete ID  athlete_age
# 55              M                 8.141          55         37.0
# 56              F                 7.211          56         43.0
# ...

# %%
#Clean up null values

# %%
FilteredDF.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# athlete_age                  575
# dtype: int64

# %%
FilteredDF[FilteredDF['athlete_age'].isna() ==1]
# Out:
#         Year of event Event dates                       Event name  \
# 453              2018  01.01.2018                    Red Eye 50km
# 456              2018  01.01.2018                    Red Eye 50km
# 459              2018  01.01.2018                    Red Eye 50km
# 460              2018  01.01.2018                    Red Eye 50km
# 13214            2018  17.03.2018  Lt. JC Stone 50K UltraMarathon
# ...               ...         ...                              ...
# 659684           2018  27.10.2018      Lake Hodges Trail Fest 50K
# 659685           2018  27.10.2018      Lake Hodges Trail Fest 50K
# 659688           2018  27.10.2018      Lake Hodges Trail Fest 50K
# 659689           2018  27.10.2018      Lake Hodges Trail Fest 50K
# 659690           2018  27.10.2018      Lake Hodges Trail Fest 50K
#
#        Event distance/length  Event number of finishers Athlete performance  \
# 453                     50km                         21
# ...

# %%
FilteredDF = FilteredDF.dropna()

# %%
FilteredDF.shape
# Out:
# (63724, 10)

# %%
#Check for duplicates

# %%
FilteredDF[FilteredDF.duplicates() == True]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21240\1226091459.py in ?()
# ----> 1 FilteredDF[FilteredDF.duplicates() == True]
#
# c:\Users\luann\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicates'

# %%
#reset index

# %%
FilteredDF.reset_index(drop = True)
# Out:
#        Year of event     Event dates  \
# 0               2018      06.01.2018
# 1               2018      06.01.2018
# 2               2018      06.01.2018
# 3               2018      06.01.2018
# 4               2018      06.01.2018
# ...              ...             ...
# 63719           2018  27.-28.10.2018
# 63720           2018  27.-28.10.2018
# 63721           2018  27.-28.10.2018
# 63722           2018  27.-28.10.2018
# 63723           2018  27.-28.10.2018
#
#                                      Event name Event distance/length  \
# 0      Yankee Springs 50 Mile Winter Challenge                   50mi
# 1      Yankee Springs 50 Mile Winter Challenge                   50mi
# 2      Yankee Springs 50 Mile Winter Challenge                   50mi
# 3      Yankee Springs 50 Mile Winter Challenge                   50mi
# 4      Yankee Springs 50 Mile Winter Challenge                   50mi
# ...                                         ...                   ...
# ...

# %%
#fix types

# %%
FilteredDF.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers    float64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                   float64
# athlete_age                  float64
# dtype: object

# %%
FilteredDF['athlete_age'] = FilteredDF['athlete_age'].astype(int)

# %%
FilteredDF.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers    float64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                   float64
# athlete_age                    int32
# dtype: object

# %%
FilteredDF['Athlete average speed'] = FilteredDF['Athlete average speed'].astype(float)

# %%
FilteredDF.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers    float64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                   float64
# athlete_age                    int32
# dtype: object

# %%
FilteredDF.head()
# Out:
#     Year of event Event dates                                Event name  \
# 55           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 56           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 57           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 58           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 59           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
#
#    Event distance/length  Event number of finishers Athlete performance  \
# 55                  50mi                        9.0
# 56                  50mi                        9.0
# 57                  50mi                        9.0
# 58                  50mi                        9.0
# 59                  50mi                        9.0
#
#    Athlete gender  Athlete average speed  Athlete ID  athlete_age
# 55              M                  8.141        55.0           37
# 56              F                  7.211        56.0           43
# ...

# %%
#Rename columns

# %%
#Year of event                  int64
#Event dates                   object
#Event name                    object
#Event distance/length         object
#Event number of finishers    float64
#Athlete performance           object
#Athlete gender                object
#Athlete average speed        float64
#Athlete ID                   float64
#athlete_age                    int32

# %%
FilteredDF= FilteredDF.rename(columns = {'Year of event': 'Year',
                                          'Event dates':  'Race_Day',
                                          'Event name':  'Race_Name',
                                         'Event distance/length': 'Race_Length',
                                         'Event number of finishers': 'Race_Number_Of_Finishers',
                                         'Athlete performance': 'Athlete_Performance',
                                         'Athlete gender': 'Athlete_Gender',
                                         'Athlete average speed': 'Athlete_Average_Speed',
                                         'Athlete ID': 'Athlete_ID',
                                         'Athlete_age': 'Athlete_Agef'          
                              })

# %%
FilteredDF.head()
# Out:
#     Year    Race_Day                                 Race_Name Race_Length  \
# 55  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 56  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 57  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 58  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 59  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
#
#     Race_Number_Of_Finishers Athlete_Performance Athlete_Gender  \
# 55                       9.0                                  M
# 56                       9.0                                  F
# 57                       9.0                                  M
# 58                       9.0                                  M
# 59                       9.0                                  M
#
#     Athlete_Average_Speed  Athlete_ID  Athlete_Agef
# 55                  8.141        55.0            37
# ...

# %%
FilteredDF= FilteredDF.rename(columns = {
                                         'Athlete_Agef': 'Athlete_Age'          
                              })

# %%
FilteredDF.head()
# Out:
#     Year    Race_Day                                 Race_Name Race_Length  \
# 55  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 56  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 57  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 58  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 59  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
#
#     Race_Number_Of_Finishers Athlete_Performance Athlete_Gender  \
# 55                       9.0                                  M
# 56                       9.0                                  F
# 57                       9.0                                  M
# 58                       9.0                                  M
# 59                       9.0                                  M
#
#     Athlete_Average_Speed  Athlete_ID  Athlete_Age
# 55                  8.141        55.0           37
# ...

# %%
#Reorder columns

# %%
ReorderedDF = FilteredDF[['Race_Day', 'Race_Name', 'Race_Length', 'Race_Number_Of_Finishers', 'Athlete_ID', 'Athlete_Gender', 'Athlete_Age', 'Athlete_Performance', 'Athlete_Average_Speed']]

# %%
ReorderedDF.head()
# Out:
#       Race_Day                                 Race_Name Race_Length  \
# 55  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 56  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 57  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 58  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 59  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
#
#     Race_Number_Of_Finishers  Athlete_ID Athlete_Gender  Athlete_Age  \
# 55                       9.0        55.0              M           37
# 56                       9.0        56.0              F           43
# 57                       9.0        57.0              M           44
# 58                       9.0        58.0              M           34
# 59                       9.0        59.0              M           32
#
#    Athlete_Performance  Athlete_Average_Speed
# 55                                      8.141
# ...

# %%
#charts and graphs

# %%
sns.histplot(ReorderedDF['Race_Length'])
# Out:
# D:\Downloads\Downloads\python\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Race_Length', ylabel='Count'>

# %%
sns.histplot(ReorderedDF, x = 'Race_Length', hue = 'Athlete_Gender')
# Out:
# D:\Downloads\Downloads\python\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Race_Length', ylabel='Count'>

# %%
sns.displot(ReorderedDF[ReorderedDF['Race_Length'] == '50mi']['Athlete_Average_Speed'])
# Out:
# D:\Downloads\Downloads\python\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.violinplot(data= ReorderedDF, x= 'Race_Length', y='Athlete_Average_Speed', hue = 'Athlete_Gender')
# Out:
# <Axes: xlabel='Race_Length', ylabel='Athlete_Average_Speed'>

# %%
sns.lmplot(ReorderedDF, x ='Athlete_Age', y='Athlete_Average_Speed')

# %%
sns.lmplot(ReorderedDF, x ='Athlete_Age', y='Athlete_Average_Speed', hue = 'Athlete_Gender')

# %%
#Questions we want to find about the data:

# %%
#Difference in speed for the 50k, 50mi for male to female

# %%
ReorderedDF.groupby(['Race_Length', 'Athlete_Gender'])['Athlete_Average_Speed'].mean()
# Out:
# Race_Length  Athlete_Gender
# 50km         F                 7.009615
#              M                 7.671578
#              X                 8.192000
# 50mi         F                 6.779836
#              M                 7.275691
#              X                 6.501000
# Name: Athlete_Average_Speed, dtype: float64

# %%
#Finding month in which each race was ran

# %%
ReorderedDF['Race_Month'] = ReorderedDF['Race_Day'].str.split('.').str.get(1).astype(int)

# %%
ReorderedDF.head()
# Out:
#       Race_Day                                 Race_Name Race_Length  \
# 55  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 56  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 57  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 58  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 59  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
#
#     Race_Number_Of_Finishers  Athlete_ID Athlete_Gender  Athlete_Age  \
# 55                       9.0        55.0              M           37
# 56                       9.0        56.0              F           43
# 57                       9.0        57.0              M           44
# 58                       9.0        58.0              M           34
# 59                       9.0        59.0              M           32
#
#    Athlete_Performance  Athlete_Average_Speed  Race_Month
# 55                                      8.141           1
# ...

# %%
#Finding season in which each race was ran

# %%
ReorderedDF['Race_Season'] = ReorderedDF['Race_Month'].apply(lambda x: 'Winter' if x > 11 else 'Fall' if x > 8 else 'Summer' if x > 5 else 'Spring' if x > 2 else 'Winter')

# %%
ReorderedDF.head(25)
# Out:
#       Race_Day                                 Race_Name Race_Length  \
# 55  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 56  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 57  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 58  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 59  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 60  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 61  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 62  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 63  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 64  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 65  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 66  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 67  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# ...

# %%
#Finding average speed per season

# %%
ReorderedDF.groupby('Race_Season')['Athlete_Average_Speed'].agg(['mean', 'count']).sort_values('mean', ascending = False)
# Out:
#                  mean  count
# Race_Season
# Spring       7.486591  20462
# Winter       7.431837  13409
# Fall         7.327393  17456
# Summer       7.121781  12397
